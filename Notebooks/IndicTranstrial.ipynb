# %%
# !git clone https://github.com/AI4Bharat/indicTrans.git
# %cd indicTrans
# clone requirements repositories
# !git clone https://github.com/anoopkunchukuttan/indic_nlp_library.git
# !git clone https://github.com/anoopkunchukuttan/indic_nlp_resources.git
# !git clone https://github.com/rsennrich/subword-nmt.git
# %cd ..
# Out:
# Cloning into 'indicTrans'...
# remote: Enumerating objects: 700, done.
# remote: Counting objects: 100% (403/403), done.
# remote: Compressing objects: 100% (163/163), done.
# remote: Total 700 (delta 280), reused 341 (delta 238), pack-reused 297
# Receiving objects: 100% (700/700), 2.64 MiB | 3.34 MiB/s, done.
# Resolving deltas: 100% (407/407), done.
# /Users/jeyam/Programming/Hackathons/Indic_Language_Support/Notebooks/indicTrans
# Cloning into 'indic_nlp_library'...
# remote: Enumerating objects: 1399, done.
# remote: Counting objects: 100% (180/180), done.
# remote: Compressing objects: 100% (57/57), done.
# remote: Total 1399 (delta 135), reused 147 (delta 120), pack-reused 1219
# Receiving objects: 100% (1399/1399), 9.57 MiB | 11.58 MiB/s, done.
# Resolving deltas: 100% (745/745), done.
# Cloning into 'indic_nlp_resources'...
# remote: Enumerating objects: 139, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 139 (delta 2), reused 2 (delta 0), pack-reused 126
# Receiving objects: 100% (139/139), 149.77 MiB | 12.74 MiB/s, done.
# Resolving deltas: 100% (53/53), done.
# Cloning into 'subword-nmt'...
# remote: Enumerating objects: 597, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 597 (delta 8), reused 12 (delta 4), pack-reused 576
# Receiving objects: 100% (597/597), 252.23 KiB | 1.22 MiB/s, done.
# Resolving deltas: 100% (357/357), done.
# /Users/jeyam/Programming/Hackathons/Indic_Language_Support/Notebooks

# %%
# !pip install sacremoses pandas mock sacrebleu tensorboardX pyarrow indic-nlp-library
! pip install mosestokenizer subword-nmt
# Install fairseq from source
# !git clone https://github.com/pytorch/fairseq.git
# %cd fairseq

# !pip install --editable ./

# %cd ..
# Out:
# Collecting sacremoses
#   Obtaining dependency information for sacremoses from https://files.pythonhosted.org/packages/0b/f0/89ee2bc9da434bd78464f288fdb346bc2932f2ee80a90b2a4bbbac262c74/sacremoses-0.1.1-py3-none-any.whl.metadata
#   Downloading sacremoses-0.1.1-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: pandas in /opt/homebrew/lib/python3.11/site-packages (2.0.3)
# Collecting mock
#   Obtaining dependency information for mock from https://files.pythonhosted.org/packages/6b/20/471f41173930550f279ccb65596a5ac19b9ac974a8d93679bcd3e0c31498/mock-5.1.0-py3-none-any.whl.metadata
#   Downloading mock-5.1.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting sacrebleu
#   Obtaining dependency information for sacrebleu from https://files.pythonhosted.org/packages/de/ea/025db0a39337b63d4728a900d262c39c3029b0fe76a9876ce6297b1aa6a0/sacrebleu-2.4.0-py3-none-any.whl.metadata
#   Downloading sacrebleu-2.4.0-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 kB 2.1 MB/s eta 0:00:00
# Collecting tensorboardX
#   Obtaining dependency information for tensorboardX from https://files.pythonhosted.org/packages/44/71/f3e7c9b2ab67e28c572ab4e9d5fa3499e0d252650f96d8a3a03e26677f53/tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Collecting pyarrow
#   Obtaining dependency information for pyarrow from https://files.pythonhosted.org/packages/de/33/fce52082865c1ad58ee3673f7cfbd19d24651ac2598244f940db29758da6/pyarrow-15.0.0-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading pyarrow-15.0.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.0 kB)
# Collecting indic-nlp-library
#   Obtaining dependency information for indic-nlp-library from https://files.pythonhosted.org/packages/ec/21/61240bcf965cedfec993497b38c42f054b149b9669e6d6cddeb1dee09d51/indic_nlp_library-0.92-py3-none-any.whl.metadata
#   Downloading indic_nlp_library-0.92-py3-none-any.whl.metadata (5.7 kB)
# Collecting regex (from sacremoses)
#   Obtaining dependency information for regex from https://files.pythonhosted.org/packages/60/9e/4b0223e05776aa3be806a902093b2ab1de3ba26b652d92065d5c7e1d4df3/regex-2023.12.25-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading regex-2023.12.25-cp311-cp311-macosx_11_0_arm64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: click in /opt/homebrew/lib/python3.11/site-packages (from sacremoses) (8.1.7)
# Requirement already satisfied: joblib in /opt/homebrew/lib/python3.11/site-packages (from sacremoses) (1.3.2)
# Requirement already satisfied: tqdm in /opt/homebrew/lib/python3.11/site-packages (from sacremoses) (4.66.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (1.23.5)
# Collecting portalocker (from sacrebleu)
#   Obtaining dependency information for portalocker from https://files.pythonhosted.org/packages/17/9e/87671efcca80ba6203811540ed1f9c0462c1609d2281d7b7f53cef05da3d/portalocker-2.8.2-py3-none-any.whl.metadata
#   Downloading portalocker-2.8.2-py3-none-any.whl.metadata (8.5 kB)
# Collecting tabulate>=0.8.9 (from sacrebleu)
#   Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting colorama (from sacrebleu)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: lxml in /opt/homebrew/lib/python3.11/site-packages (from sacrebleu) (4.9.3)
# Requirement already satisfied: packaging in /opt/homebrew/lib/python3.11/site-packages (from tensorboardX) (23.1)
# Requirement already satisfied: protobuf>=3.20 in /opt/homebrew/lib/python3.11/site-packages (from tensorboardX) (4.23.4)
# Collecting sphinx-argparse (from indic-nlp-library)
#   Downloading sphinx_argparse-0.4.0-py3-none-any.whl (12 kB)
# Collecting sphinx-rtd-theme (from indic-nlp-library)
#   Obtaining dependency information for sphinx-rtd-theme from https://files.pythonhosted.org/packages/ea/46/00fda84467815c29951a9c91e3ae7503c409ddad04373e7cfc78daad4300/sphinx_rtd_theme-2.0.0-py2.py3-none-any.whl.metadata
#   Downloading sphinx_rtd_theme-2.0.0-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting morfessor (from indic-nlp-library)
#   Downloading Morfessor-2.0.6-py3-none-any.whl (35 kB)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Collecting sphinx>=1.2.0 (from sphinx-argparse->indic-nlp-library)
#   Obtaining dependency information for sphinx>=1.2.0 from https://files.pythonhosted.org/packages/b2/b6/8ed35256aa530a9d3da15d20bdc0ba888d5364441bb50a5a83ee7827affe/sphinx-7.2.6-py3-none-any.whl.metadata
#   Downloading sphinx-7.2.6-py3-none-any.whl.metadata (5.9 kB)
# Collecting docutils<0.21 (from sphinx-rtd-theme->indic-nlp-library)
#   Obtaining dependency information for docutils<0.21 from https://files.pythonhosted.org/packages/26/87/f238c0670b94533ac0353a4e2a1a771a0cc73277b88bff23d3ae35a256c1/docutils-0.20.1-py3-none-any.whl.metadata
#   Downloading docutils-0.20.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting sphinxcontrib-jquery<5,>=4 (from sphinx-rtd-theme->indic-nlp-library)
#   Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 5.0 MB/s eta 0:00:00
# Collecting sphinxcontrib-applehelp (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library)
#   Obtaining dependency information for sphinxcontrib-applehelp from https://files.pythonhosted.org/packages/56/89/fea3fbf6785b388e6cb8a1beaf62f96e80b37311bdeed6e133388a732426/sphinxcontrib_applehelp-1.0.8-py3-none-any.whl.metadata
#   Downloading sphinxcontrib_applehelp-1.0.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting sphinxcontrib-devhelp (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library)
#   Obtaining dependency information for sphinxcontrib-devhelp from https://files.pythonhosted.org/packages/a0/52/1049d918d1d1c72857d285c3f0c64c1cbe0be394ce1c93a3d2aa4f39fe3b/sphinxcontrib_devhelp-1.0.6-py3-none-any.whl.metadata
#   Downloading sphinxcontrib_devhelp-1.0.6-py3-none-any.whl.metadata (2.3 kB)
# Collecting sphinxcontrib-jsmath (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library)
#   Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (5.1 kB)
# Collecting sphinxcontrib-htmlhelp>=2.0.0 (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library)
#   Obtaining dependency information for sphinxcontrib-htmlhelp>=2.0.0 from https://files.pythonhosted.org/packages/c2/e9/74c4cda5b409af3222fda38f0774e616011bc935f639dbc0da5ca2d1be7d/sphinxcontrib_htmlhelp-2.0.5-py3-none-any.whl.metadata
#   Downloading sphinxcontrib_htmlhelp-2.0.5-py3-none-any.whl.metadata (2.3 kB)
# Collecting sphinxcontrib-serializinghtml>=1.1.9 (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library)
#   Obtaining dependency information for sphinxcontrib-serializinghtml>=1.1.9 from https://files.pythonhosted.org/packages/38/24/228bb903ea87b9e08ab33470e6102402a644127108c7117ac9c00d849f82/sphinxcontrib_serializinghtml-1.1.10-py3-none-any.whl.metadata
#   Downloading sphinxcontrib_serializinghtml-1.1.10-py3-none-any.whl.metadata (2.4 kB)
# Collecting sphinxcontrib-qthelp (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library)
#   Obtaining dependency information for sphinxcontrib-qthelp from https://files.pythonhosted.org/packages/80/b3/1beac14a88654d2e5120d0143b49be5ad450b86eb1963523d8dbdcc51eb2/sphinxcontrib_qthelp-1.0.7-py3-none-any.whl.metadata
#   Downloading sphinxcontrib_qthelp-1.0.7-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: Jinja2>=3.0 in /opt/homebrew/lib/python3.11/site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (3.1.2)
# Requirement already satisfied: Pygments>=2.14 in /Users/jeyam/Library/Python/3.11/lib/python/site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.15.1)
# Collecting snowballstemmer>=2.0 (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library)
#   Downloading snowballstemmer-2.2.0-py2.py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.0/93.0 kB 11.9 MB/s eta 0:00:00
# Collecting babel>=2.9 (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library)
#   Obtaining dependency information for babel>=2.9 from https://files.pythonhosted.org/packages/0d/35/4196b21041e29a42dc4f05866d0c94fa26c9da88ce12c38c2265e42c82fb/Babel-2.14.0-py3-none-any.whl.metadata
#   Downloading Babel-2.14.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting alabaster<0.8,>=0.7 (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library)
#   Obtaining dependency information for alabaster<0.8,>=0.7 from https://files.pythonhosted.org/packages/32/34/d4e1c02d3bee589efb5dfa17f88ea08bdb3e3eac12bc475462aec52ed223/alabaster-0.7.16-py3-none-any.whl.metadata
#   Downloading alabaster-0.7.16-py3-none-any.whl.metadata (2.9 kB)
# Collecting imagesize>=1.3 (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library)
#   Downloading imagesize-1.4.1-py2.py3-none-any.whl (8.8 kB)
# Requirement already satisfied: requests>=2.25.0 in /opt/homebrew/lib/python3.11/site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/lib/python3.11/site-packages (from Jinja2>=3.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests>=2.25.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.11/site-packages (from requests>=2.25.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/lib/python3.11/site-packages (from requests>=2.25.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.11/site-packages (from requests>=2.25.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2023.7.22)
# Downloading sacremoses-0.1.1-py3-none-any.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 14.6 MB/s eta 0:00:00a 0:00:01
# Downloading mock-5.1.0-py3-none-any.whl (30 kB)
# Downloading sacrebleu-2.4.0-py3-none-any.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.3/106.3 kB 15.0 MB/s eta 0:00:00
# Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 14.3 MB/s eta 0:00:00
# Downloading pyarrow-15.0.0-cp311-cp311-macosx_11_0_arm64.whl (24.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 7.6 MB/s eta 0:00:0000:0100:01m
# Downloading indic_nlp_library-0.92-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 2.4 MB/s eta 0:00:00
# Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Downloading regex-2023.12.25-cp311-cp311-macosx_11_0_arm64.whl (291 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 291.0/291.0 kB 7.8 MB/s eta 0:00:00:00:01
# Downloading sphinx_rtd_theme-2.0.0-py2.py3-none-any.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 9.7 MB/s eta 0:00:00ta 0:00:01
# Downloading docutils-0.20.1-py3-none-any.whl (572 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.7/572.7 kB 9.3 MB/s eta 0:00:00ta 0:00:01
# Downloading sphinx-7.2.6-py3-none-any.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 10.2 MB/s eta 0:00:00a 0:00:01
# Downloading alabaster-0.7.16-py3-none-any.whl (13 kB)
# Downloading Babel-2.14.0-py3-none-any.whl (11.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 11.1 MB/s eta 0:00:0000:0100:01
# Downloading sphinxcontrib_htmlhelp-2.0.5-py3-none-any.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 kB 6.8 MB/s eta 0:00:00
# Downloading sphinxcontrib_serializinghtml-1.1.10-py3-none-any.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.7/92.7 kB 7.1 MB/s eta 0:00:00
# Downloading sphinxcontrib_applehelp-1.0.8-py3-none-any.whl (120 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.0/120.0 kB 8.5 MB/s eta 0:00:00
# Downloading sphinxcontrib_devhelp-1.0.6-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.5/83.5 kB 8.5 MB/s eta 0:00:00
# Downloading sphinxcontrib_qthelp-1.0.7-py3-none-any.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.4/89.4 kB 7.3 MB/s eta 0:00:00
# Installing collected packages: snowballstemmer, morfessor, tensorboardX, tabulate, sphinxcontrib-serializinghtml, sphinxcontrib-qthelp, sphinxcontrib-jsmath, sphinxcontrib-htmlhelp, sphinxcontrib-devhelp, sphinxcontrib-applehelp, regex, pyarrow, portalocker, mock, imagesize, docutils, colorama, babel, alabaster, sphinx, sacremoses, sacrebleu, sphinxcontrib-jquery, sphinx-argparse, sphinx-rtd-theme, indic-nlp-library
# Successfully installed alabaster-0.7.16 babel-2.14.0 colorama-0.4.6 docutils-0.20.1 imagesize-1.4.1 indic-nlp-library-0.92 mock-5.1.0 morfessor-2.0.6 portalocker-2.8.2 pyarrow-15.0.0 regex-2023.12.25 sacrebleu-2.4.0 sacremoses-0.1.1 snowballstemmer-2.2.0 sphinx-7.2.6 sphinx-argparse-0.4.0 sphinx-rtd-theme-2.0.0 sphinxcontrib-applehelp-1.0.8 sphinxcontrib-devhelp-1.0.6 sphinxcontrib-htmlhelp-2.0.5 sphinxcontrib-jquery-4.1 sphinxcontrib-jsmath-1.0.1 sphinxcontrib-qthelp-1.0.7 sphinxcontrib-serializinghtml-1.1.10 tabulate-0.9.0 tensorboardX-2.6.2.2
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Collecting mosestokenizer
#   Downloading mosestokenizer-1.2.1.tar.gz (37 kB)
#   Preparing metadata (setup.py) ... done
# Collecting subword-nmt
#   Downloading subword_nmt-0.3.8-py3-none-any.whl (27 kB)
# Collecting docopt (from mosestokenizer)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting openfile (from mosestokenizer)
#   Downloading openfile-0.0.7-py3-none-any.whl (2.4 kB)
# Collecting uctools (from mosestokenizer)
#   Downloading uctools-1.3.0.tar.gz (4.6 kB)
#   Preparing metadata (setup.py) ... done
# Collecting toolwrapper (from mosestokenizer)
#   Downloading toolwrapper-2.1.0.tar.gz (3.2 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: mock in /opt/homebrew/lib/python3.11/site-packages (from subword-nmt) (5.1.0)
# Requirement already satisfied: tqdm in /opt/homebrew/lib/python3.11/site-packages (from subword-nmt) (4.66.1)
# Building wheels for collected packages: mosestokenizer, docopt, toolwrapper, uctools
#   Building wheel for mosestokenizer (setup.py) ... done
#   Created wheel for mosestokenizer: filename=mosestokenizer-1.2.1-py3-none-any.whl size=49170 sha256=67ac5f8b308b84159046093c11292927e52fc87b73f1863f342acdc9ef1b6b2c
#   Stored in directory: /Users/jeyam/Library/Caches/pip/wheels/34/cc/6e/444b747bf2adc6a0530acd6a7afda9f908b219906cfd4df2e7
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13705 sha256=2017b17f9f241b842dac2bd858604d1cc70eb18357451c5ed4d0ca80c869272e
#   Stored in directory: /Users/jeyam/Library/Caches/pip/wheels/1a/b0/8c/4b75c4116c31f83c8f9f047231251e13cc74481cca4a78a9ce
#   Building wheel for toolwrapper (setup.py) ... done
#   Created wheel for toolwrapper: filename=toolwrapper-2.1.0-py3-none-any.whl size=3337 sha256=dea53df8085a99efab5947a1d84065378c77586ccc560932a2cc25e3d6861e49
#   Stored in directory: /Users/jeyam/Library/Caches/pip/wheels/28/b0/06/bccd361b5b8bbf1ec88b72164fa52daaaa2221865fb980dff1
#   Building wheel for uctools (setup.py) ... done
#   Created wheel for uctools: filename=uctools-1.3.0-py3-none-any.whl size=6149 sha256=4e5434fa6908d07bef1710c5192a400dbaae466e76728c2fc6b56b61983c5315
#   Stored in directory: /Users/jeyam/Library/Caches/pip/wheels/ad/d6/21/763477f07e94a9d2567147f91d34897dfd1eb1062350302969
# Successfully built mosestokenizer docopt toolwrapper uctools
# Installing collected packages: toolwrapper, openfile, docopt, uctools, subword-nmt, mosestokenizer
# Successfully installed docopt-0.6.2 mosestokenizer-1.2.1 openfile-0.0.7 subword-nmt-0.3.8 toolwrapper-2.1.0 uctools-1.3.0
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Cloning into 'fairseq'...
# remote: Enumerating objects: 35100, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 35100 (delta 18), reused 38 (delta 17), pack-reused 35057
# Receiving objects: 100% (35100/35100), 25.14 MiB | 9.63 MiB/s, done.
# Resolving deltas: 100% (25478/25478), done.
# /Users/jeyam/Programming/Hackathons/Indic_Language_Support/Notebooks/fairseq
# Obtaining file:///Users/jeyam/Programming/Hackathons/Indic_Language_Support/Notebooks/fairseq
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Collecting cffi (from fairseq==0.12.2)
#   Obtaining dependency information for cffi from https://files.pythonhosted.org/packages/18/6c/0406611f3d5aadf4c5b08f6c095d874aed8dfc2d3a19892707d72536d5dc/cffi-1.16.0-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading cffi-1.16.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (1.5 kB)
# Collecting cython (from fairseq==0.12.2)
#   Obtaining dependency information for cython from https://files.pythonhosted.org/packages/e3/7f/f584f5d15323feb897d42ef0e9d910649e2150d7a30cf7e7a8cc1d236e6f/Cython-3.0.8-py2.py3-none-any.whl.metadata
#   Using cached Cython-3.0.8-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting hydra-core<1.1,>=1.0.7 (from fairseq==0.12.2)
#   Downloading hydra_core-1.0.7-py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.8/123.8 kB 2.9 MB/s eta 0:00:0000:01
# Collecting omegaconf<2.1 (from fairseq==0.12.2)
#   Downloading omegaconf-2.0.6-py3-none-any.whl (36 kB)
# Requirement already satisfied: numpy>=1.21.3 in /opt/homebrew/lib/python3.11/site-packages (from fairseq==0.12.2) (1.23.5)
# Requirement already satisfied: regex in /opt/homebrew/lib/python3.11/site-packages (from fairseq==0.12.2) (2023.12.25)
# Requirement already satisfied: sacrebleu>=1.4.12 in /opt/homebrew/lib/python3.11/site-packages (from fairseq==0.12.2) (2.4.0)
# Collecting torch>=1.13 (from fairseq==0.12.2)
#   Obtaining dependency information for torch>=1.13 from https://files.pythonhosted.org/packages/96/4e/970cd3e13ad95aed81102272f0678d8cc48101880b8be5bae8aad22e7f3b/torch-2.2.0-cp311-none-macosx_11_0_arm64.whl.metadata
#   Using cached torch-2.2.0-cp311-none-macosx_11_0_arm64.whl.metadata (25 kB)
# Requirement already satisfied: tqdm in /opt/homebrew/lib/python3.11/site-packages (from fairseq==0.12.2) (4.66.1)
# Collecting bitarray (from fairseq==0.12.2)
#   Obtaining dependency information for bitarray from https://files.pythonhosted.org/packages/06/60/c1a419f8abd0c9d2641e3e570fc63ad3a87a63ef88a362900e3254f780bc/bitarray-2.9.2-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading bitarray-2.9.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (34 kB)
# Collecting torchaudio>=0.8.0 (from fairseq==0.12.2)
#   Obtaining dependency information for torchaudio>=0.8.0 from https://files.pythonhosted.org/packages/79/f7/5929802a1d14693d2dea6e60c51a923724348f134a91558f22bc686d3d8b/torchaudio-2.2.0-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading torchaudio-2.2.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.4 kB)
# Requirement already satisfied: scikit-learn in /opt/homebrew/lib/python3.11/site-packages (from fairseq==0.12.2) (1.3.0)
# Requirement already satisfied: packaging in /opt/homebrew/lib/python3.11/site-packages (from fairseq==0.12.2) (23.1)
# Collecting antlr4-python3-runtime==4.8 (from hydra-core<1.1,>=1.0.7->fairseq==0.12.2)
#   Downloading antlr4-python3-runtime-4.8.tar.gz (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.4/112.4 kB 6.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PyYAML>=5.1.* in /opt/homebrew/lib/python3.11/site-packages (from omegaconf<2.1->fairseq==0.12.2) (6.0.1)
# Requirement already satisfied: typing-extensions in /opt/homebrew/lib/python3.11/site-packages (from omegaconf<2.1->fairseq==0.12.2) (4.5.0)
# Requirement already satisfied: portalocker in /opt/homebrew/lib/python3.11/site-packages (from sacrebleu>=1.4.12->fairseq==0.12.2) (2.8.2)
# Requirement already satisfied: tabulate>=0.8.9 in /opt/homebrew/lib/python3.11/site-packages (from sacrebleu>=1.4.12->fairseq==0.12.2) (0.9.0)
# Requirement already satisfied: colorama in /opt/homebrew/lib/python3.11/site-packages (from sacrebleu>=1.4.12->fairseq==0.12.2) (0.4.6)
# Requirement already satisfied: lxml in /opt/homebrew/lib/python3.11/site-packages (from sacrebleu>=1.4.12->fairseq==0.12.2) (4.9.3)
# Requirement already satisfied: filelock in /opt/homebrew/lib/python3.11/site-packages (from torch>=1.13->fairseq==0.12.2) (3.12.2)
# Collecting typing-extensions (from omegaconf<2.1->fairseq==0.12.2)
#   Obtaining dependency information for typing-extensions from https://files.pythonhosted.org/packages/b7/f4/6a90020cd2d93349b442bfcb657d0dc91eee65491600b2cb1d388bc98e6b/typing_extensions-4.9.0-py3-none-any.whl.metadata
#   Using cached typing_extensions-4.9.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting sympy (from torch>=1.13->fairseq==0.12.2)
#   Using cached sympy-1.12-py3-none-any.whl (5.7 MB)
# Requirement already satisfied: networkx in /opt/homebrew/lib/python3.11/site-packages (from torch>=1.13->fairseq==0.12.2) (3.1)
# Requirement already satisfied: jinja2 in /opt/homebrew/lib/python3.11/site-packages (from torch>=1.13->fairseq==0.12.2) (3.1.2)
# Collecting fsspec (from torch>=1.13->fairseq==0.12.2)
#   Obtaining dependency information for fsspec from https://files.pythonhosted.org/packages/ad/30/2281c062222dc39328843bd1ddd30ff3005ef8e30b2fd09c4d2792766061/fsspec-2024.2.0-py3-none-any.whl.metadata
#   Using cached fsspec-2024.2.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting pycparser (from cffi->fairseq==0.12.2)
#   Using cached pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Requirement already satisfied: scipy>=1.5.0 in /opt/homebrew/lib/python3.11/site-packages (from scikit-learn->fairseq==0.12.2) (1.11.2)
# Requirement already satisfied: joblib>=1.1.1 in /opt/homebrew/lib/python3.11/site-packages (from scikit-learn->fairseq==0.12.2) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/homebrew/lib/python3.11/site-packages (from scikit-learn->fairseq==0.12.2) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/lib/python3.11/site-packages (from jinja2->torch>=1.13->fairseq==0.12.2) (2.1.3)
# Collecting mpmath>=0.19 (from sympy->torch>=1.13->fairseq==0.12.2)
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached torch-2.2.0-cp311-none-macosx_11_0_arm64.whl (59.4 MB)
# Downloading torchaudio-2.2.0-cp311-cp311-macosx_11_0_arm64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 12.2 MB/s eta 0:00:0000:0100:01
# Downloading bitarray-2.9.2-cp311-cp311-macosx_11_0_arm64.whl (124 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.6/124.6 kB 9.4 MB/s eta 0:00:00
# Downloading cffi-1.16.0-cp311-cp311-macosx_11_0_arm64.whl (176 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.7/176.7 kB 17.3 MB/s eta 0:00:00
# Using cached Cython-3.0.8-py2.py3-none-any.whl (1.2 MB)
# Using cached typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Using cached fsspec-2024.2.0-py3-none-any.whl (170 kB)
# Building wheels for collected packages: fairseq, antlr4-python3-runtime
#   Building editable for fairseq (pyproject.toml) ... done
#   Created wheel for fairseq: filename=fairseq-0.12.2-0.editable-cp311-cp311-macosx_14_0_arm64.whl size=9445 sha256=646503d628df27cc0ebe7a512a24cf0077d831d2e3e533bae4250ebb40f8e22b
#   Stored in directory: /private/var/folders/m4/817lmlzx26df805ztf8tvs7r0000gn/T/pip-ephem-wheel-cache-usdpej9d/wheels/af/cd/c8/651ef0c093f8cd0dd4fc671ae264d59697072cbac1bad848a2
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.8-py3-none-any.whl size=141209 sha256=11d3460298902b41ec50e129c94ba349857674c1877ea45d25ba966848627796
#   Stored in directory: /Users/jeyam/Library/Caches/pip/wheels/21/10/be/9a70640a3a60ed4a7e1a45e49bb9f58b04692d5d7b517bd39e
# Successfully built fairseq antlr4-python3-runtime
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: mpmath, bitarray, antlr4-python3-runtime, typing-extensions, sympy, pycparser, fsspec, cython, torch, omegaconf, cffi, torchaudio, hydra-core, fairseq
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-macos 2.13.0 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.9.0 which is incompatible.
# Successfully installed antlr4-python3-runtime-4.8 bitarray-2.9.2 cffi-1.16.0 cython-3.0.8 fairseq-0.12.2 fsspec-2024.2.0 hydra-core-1.0.7 mpmath-1.3.0 omegaconf-2.0.6 pycparser-2.21 sympy-1.12 torch-2.2.0 torchaudio-2.2.0 typing-extensions-4.9.0
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# /Users/jeyam/Programming/Hackathons/Indic_Language_Support/Notebooks

# %%
# download the indictrans model


# downloading the indic-en model
# !wget https://storage.googleapis.com/samanantar-public/V0.2/models/indic-en.zip
# !unzip indic-en.zip

# downloading the en-indic model
# !curl https://storage.googleapis.com/samanantar-public/V0.2/models/en-indic.zip
# !unzip en-indic.zip

# # downloading the indic-indic model
# !wget https://storage.googleapis.com/samanantar-public/V0.3/models/m2m.zip
# !unzip m2m.zip

# %cd indicTrans
# Out:
# /Users/jeyam/Programming/Hackathons/Indic_Language_Support/Notebooks/indicTrans
